# %%
# Store Inventory 

# Display the shape of the DataFrame.
# Display all column names.

# %%
import pandas as pd

df = pd.DataFrame({
    "Product": ["Pen", "Notebook", "Pencil", "Eraser", "Marker"],
    "Price": [10, 120, 5, 8, 35],
    "Stock": [50, 25, 100, 60, 40]
})

print(df)
# Out:
#     Product  Price  Stock
# 0       Pen     10     50
# 1  Notebook    120     25
# 2    Pencil      5    100
# 3    Eraser      8     60
# 4    Marker     35     40

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Product', 'Price', 'Stock'], dtype='object')
